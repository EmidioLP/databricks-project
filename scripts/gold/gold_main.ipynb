# %% [markdown]
# Este notebook executa programaticamente todos os notebooks da camada de Gold em sequência.
# Ele se torna o ponto de entrada único para a camada Gold no Databricks.

# %%
notebooks = [
    "./gold_dim_customers",
    "./gold_dim_products",
    "./gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
